# %% [markdown]
# ## Enhancing 14th Century Artwork Through Modern AI Tools
#
# ### Introduction
# For this project I selected a cultural heritage object from th eUniversity of Glasgow Archives and Special Collections. I decided to choose a collection of letters that had been extracted from a 14th century Caramelite Missal. The object was accessed through the University of Glasgow's digital collections, and the specific item can be found here: ([Source](https://www.gla.ac.uk/collections/#/details?irn=260822&catType=C))
#
# I chose this object due to the small hidden pieces of artwork that is displayed inside each letter.My aim with this project is to highlight the art using artificial intelligence (AI). When first handling the object, I did not see the small illustrations I had to look particularly close in order to be abe to see them, even then, I could not fully see what they were depicting. Therefore, through the use of image enhancing AI I will attempt to enhance the lost details of this medeival manuscript.
#
# ### About the Object
# A missal is a collection of religeous texts and prayers and was a popular liturgical book dating back to the 5th century ([Source](https://www.britannica.com/topic/missal)). When considering the fact that these letters from this manuscript were once part of a complete missal, it is worth considering the time and skill it took to create such detailed images. Some of the letters in this manuscript are incredeibly small and the illustrations within them are almost invisible at first glance, this heavily influenced my motivation for this project as I felt that such skill deserved to be amplified rather than missed by anyone that views the collection.
#
#
# ### Objectives
# The main objectives of this portfolio are to explore and demonstrate how AI tools can be applied to cultural heritage objects and assess the potential that AI could have in shedding a new perspective on historical objects, whilst also analysing how the AI interperates prompts and images. Specifically with a focus on this 14th century missal.
#
# A key objective is to explore how AI can enhance or reveal details that the human eye might miss or that the process od time may have damaged. By enhancing these componants this project aims to shed a new perspective on the manuscript and show off its striking visual features and promote a deeper engagement with the object.
#
# In addition to this, this project aims to assess how different AI tools interperate textual prompts and visual inputs. By comparing the output of both AI tools, this project will explore how the input prompt influences the output and how different models respond to the same promts.
#
# Lastly, this project will explore how AI and human collaboraition can impact engagement with heritage objects and whether the output of the AI benefits the material or influences human interpretation.
#
# ### Methodology
# This project involved selecting four images of different letters from the collection as well as a handwritten note. I chose them due to their varying levels of detail and size.
#
# I uploaded the images ChatGPT and Kling AI which then generated new images based on various textual prompts, the reults are impacted by the prompt and the training model of the AI itself.
#
# The prompts I created were formed with the intention of preserving the historical value and overall medieval style of the letters. For some of the letters, I used different prompts for the same image in order to assess the difference in the output based on how varying levels of detail from the input. In addition to this, the same image was processed using the same prompt but by two different AI models. This was done in order to analyise the difference in interpretation and style between the two models.
#
# Following feedback from my peer support group, I decided also to analyse the handwritten page from the missal. Some words were difficult to read due to the writing style and potential variations of language terminology. I uploaded the image of the text to ChatGPT to explore how the AI interpretes and reconstructs unclear text.This then enabled a further comparison between how AI interprets text versus visual, and to understand how AI can assist in general historical interpretation.
#
#
# ### AI and Human Collaboration
# #### What is AI?
#
# AI models such as the ones used for this project operate using generative systems that learn patterns from large datasets. Generative AI models such as ChatGPT use machine leraning technologies to analyse existing data and generate new data that could plausibly be part of the original dataset ([Source](https://link.springer.com/article/10.1007/s00163-024-00441-x)).
#
# #### Human & AI Collaboration
# The results of this project are produced using both machine generation and human input. I formed carefully worded prompts, ensuring that I provided clear contextualised prompts to directly influence the output that the AI would produce.
#
# I experimented with different levels of context when giving ChatGPT prompts, I analysed and compared the different outputs before forming my final prompt. I ensured that the prompts were formulated to maintain the historic and medieval styles of the original image.
#
# In addition to this, the two different tools that I selected interpreted the prompts I had created differently. The prompt I designed for ChatGPT produced a very different result when submitted to Kling AI. This highlights how the outputs are produced based on human decision-making and the machine programming and interpretation.
#
# The collaboration between human and machine highlights how AI can be used to interpret historical material while heavily relying on human inout to influence the outcome.
#
#
#
#
# ### Prompts and Results
#
# ### Reflection
