# %% [markdown]
# Project test

# %%
print ("this is me testing the code for this cell")
# Out:
# this is me testing the code for this cell

# %% [markdown]
# Project Idea:

# %%
print("Chosen Object: MS Euing 26 - Volume of initial letters, etc., extracted from a 14th century Carmelite missal.\n" "https://www.gla.ac.uk/collections/#/details?irn=260822&catType=C.\n"
      "Goal with AI:\n"
      "Use generative AI to enhance and bring to life the images drawn inside the letters.")
# Out:
# Chosen Object: MS Euing 26 - Volume of initial letters, etc., extracted from a 14th century Carmelite missal.
# https://www.gla.ac.uk/collections/#/details?irn=260822&catType=C.
# Goal with AI:
# Use generative AI to enhance and bring to life the images drawn inside the letters.
